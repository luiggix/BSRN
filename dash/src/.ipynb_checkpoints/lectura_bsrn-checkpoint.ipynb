# %%
import pandas as pd

# %%
bsrn = pd.read_csv('bsrn.csv')

# %%
bsrn
# Out:
#                   TIMESTAMP  RECORD   ZenDeg    AzDeg  AirMass  \
# 0       2022-04-01 00:00:00  345077  159.455  351.516      0.0
# 1       2022-04-01 00:01:00  345078  159.489  352.220      0.0
# 2       2022-04-01 00:02:00  345079  159.520  352.926      0.0
# 3       2022-04-01 00:03:00  345080  159.547  353.635      0.0
# 4       2022-04-01 00:04:00  345081  159.572  354.345      0.0
# ...                     ...     ...      ...      ...      ...
# 130978  2022-06-30 23:55:00   34023  140.893  353.867      0.0
# 130979  2022-06-30 23:56:00   34024  140.918  354.230      0.0
# 130980  2022-06-30 23:57:00   34025  140.941  354.593      0.0
# 130981  2022-06-30 23:58:00   34026  140.964  354.957      0.0
# 130982  2022-06-30 23:59:00   34027  140.984  355.321      0.0
#
#         CRBattVolt_Avg  CRPTemp_Avg  ProcessTime_s_Max  GLOBAL_Avg  \
# 0                12.56        33.59              0.903   -0.111028
# 1                12.56        33.59              0.902   -0.074018
# ...

# %%
bsrn.columns
# Out:
# Index(['TIMESTAMP', 'RECORD', 'ZenDeg', 'AzDeg', 'AirMass', 'CRBattVolt_Avg',
#        'CRPTemp_Avg', 'ProcessTime_s_Max', 'GLOBAL_Avg', 'GLOBAL_Std',
#        'GLOBAL_Min', 'GLOBAL_Max', 'DIRECT_Avg', 'DIRECT_Std', 'DIRECT_Min',
#        'DIRECT_Max', 'DIFFUSE_Avg', 'DIFFUSE_Std', 'DIFFUSE_Min',
#        'DIFFUSE_Max', 'UPWARD_SW_Avg', 'UPWARD_SW_Std', 'UPWARD_SW_Min',
#        'UPWARD_SW_Max', 'DOWNWARD_Avg', 'DOWNWARD_Std', 'DOWNWARD_Min',
#        'DOWNWARD_Max', 'DWIRTEMP_Avg', 'DWIRTEMP_Std', 'DWIRTEMP_Min',
#        'DWIRTEMP_Max', 'UPWARD_LW_Avg', 'UPWARD_LW_Std', 'UPWARD_LW_Min',
#        'UPWARD_LW_Max', 'UWIRTEMP_Avg', 'UWIRTEMP_Std', 'UWIRTEMP_Min',
#        'UWIRTEMP_Max', 'DNITEMPC_Avg', 'DNITEMPC_Std', 'DNITEMPC_Min',
#        'DNITEMPC_Max', 'UVB_Avg', 'UVB_Std', 'UVB_Min', 'UVB_Max', 'SOIL_Avg',
#        'AIR_TEMPERATURE_Avg', 'RELATIVE_HUMIDITY_Avg', 'DEW_POINT_Avg',
#        'PRESSURE_Avg', 'GLOBTT_Avg', 'GLOBTT_Std', 'GLOBTT_Min', 'GLOBTT_Max',
# ...

# %%
bsrn.plot(x= 'TIMESTAMP', y='GLOBAL_Std', rot=45)
# Out:
# <AxesSubplot:xlabel='TIMESTAMP'>
